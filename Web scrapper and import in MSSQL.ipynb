# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
site = requests.get(r'https://www.tgju.org/%D9%82%DB%8C%D9%85%D8%AA-%D8%AF%D9%84%D8%A7%D8%B1')

# %%
soup = BeautifulSoup(site.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-dir="rtl" data-revision="2023033121" dir="rtl" lang="fa">
#  <head>
#   <title>
#    قیمت دلار | شبکه اطلاع‌ رسانی طلا و ارز
#   </title>
#   <meta charset="utf-8"/>
#   <script src="/cdn-cgi/apps/head/ks0hMfVvAzzkfKN7j9EQZgwSuNE.js">
#   </script>
#   <link href="https://static.tgju.org" rel="preconnect"/>
#   <link href="https://call.tgju.org" rel="preconnect"/>
#   <link href="https://static.tgju.org" rel="dns-prefetch"/>
#   <link href="https://call.tgju.org" rel="dns-prefetch"/>
#   <meta content="Vandaw Parin 2.0 (vandaw.com/parin)" name="generator"/>
#   <link href="https://www.tgju.org/opensearch.xml" rel="search" title="TGJU" type="application/opensearchdescription+xml"/>
#   <base href="https://www.tgju.org/"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="#35608c" name="theme-color"/>
#   <link href="https://www.tgju.org/touch-icon-ipad.png" rel="apple-touch-icon" sizes="180x180"/>
# ...

# %%
tags = soup.html.children
list[tags]
print("----------------------------")
for tag in tags:
    if tag.name != None:
        print(tag.name)
# Out:
# ----------------------------
# head
# body

# %%
tags = soup.html.body.main.section.div.div.children
for tag in tags:
    if tag.name != None:
        print(tag.name)
# Out:
# h3
# div

# %%
div = soup.find_all("class")

div
# Out:
# []

# %%
for i in range(12):
    print(soup.body.find(id="main").tbody.find_all("td",class_="nf")[i].text)
# Out:
# 472,080
# (0%) 0
# 398,382
# (0%) 0
# 362,706
# (0%) 0
# 420,750
# (0%) 0
# 393996
# (0%) 0
# 500,000
# (0%) 0

# %%
soup.body.find(id="main").tbody.find("tr",class_="pointer").find_next_sibling("tr").text
# Out:
# '\n دلار سنا / خرید\n398,382\n(0%) 0\n398,382\n398,382\n۲۵ اسفند\n\n'

# %%
soup.body.find(id="main").tbody.find_all(["tr" and "td"])[0:5]
# Out:
# [<td class="nf">472,080</td>,
#  <td class="nf"><span class="">(0%) 0</span></td>,
#  <td>460,800</td>,
#  <td>472,100</td>,
#  <td>۲۸ اسفند</td>]

# %%
#//*[@id="main"]/div[1]/div[3]/div[1]/div/div/div[1]/table/tbody/tr[1]/th
#//*[@id="main"]/div[1]/div[3]/div[1]/div/div/div[1]/table/tbody/tr[3]/th/span
soup.body.find(id="main").tbody.find_all(["th" ])
# Out:
# [<th><span class="flag flag-usd"><span></span></span> دلار</th>,
#  <th><span class="flag flag-usd"><span></span></span> دلار سنا / خرید</th>,
#  <th><span class="flag flag-usd"><span></span></span> دلار نیما / خرید</th>,
#  <th><span class="flag flag-usd"><span></span></span> دلار صرافی‌ ملی / خرید</th>,
#  <th><span class="flag flag-usd"><span></span></span> دلار توافقی</th>,
#  <th><span class="flag flag-usd"><span></span></span> دلار هرات</th>]

# %%
a=[]

for j in range(1):
    a.append(soup.body.find(id="main").tbody.find_all(["th" ])[j].text)
    for i in range(35):
        if soup.body.find(id="main").tbody.find_all(["tr" and "td"])[i].text=='' and j+1<6:
            j=j+1
            i=i+1
            a.append(soup.body.find(id="main").tbody.find_all(["th" ])[j].text)
        
        else :
            a.append(soup.body.find(id="main").tbody.find_all(["tr" and "td"])[i].text)
            i=i+1
a
# Out:
# [' دلار',
#  '472,080',
#  '(0%) 0',
#  '460,800',
#  '472,100',
#  '۲۸ اسفند',
#  ' دلار سنا / خرید',
#  '398,382',
#  '(0%) 0',
#  '398,382',
#  '398,382',
#  '۲۵ اسفند',
#  ' دلار نیما / خرید',
#  '362,706',
#  '(0%) 0',
#  '362,706',
#  '362,706',
#  '۲۵ اسفند',
#  ' دلار صرافی\u200c ملی / خرید',
#  '420,750',
#  '(0%) 0',
#  '420,750',
#  '420,750',
#  '۲۳ اسفند',
#  ' دلار توافقی',
#  '393996',
#  '(0%) 0',
#  '393366',
#  '394535',
#  '۳ بهمن',
#  ' دلار هرات',
#  '500,000',
#  '(0%) 0',
#  '475,000',
#  '500,000',
#  '۲۸ اسفند']

# %%
dt=[]
for i in range(35):
        if soup.body.find(id="main").tbody.find_all(["tr" and "td"])[i].text=='':
            i=i+1
            
        else :
            dt.append(soup.body.find(id="main").tbody.find_all(["tr" and "td"])[i].text)
            i=i+1
dt
# Out:
# ['472,080',
#  '(0%) 0',
#  '460,800',
#  '472,100',
#  '۲۸ اسفند',
#  '398,382',
#  '(0%) 0',
#  '398,382',
#  '398,382',
#  '۲۵ اسفند',
#  '362,706',
#  '(0%) 0',
#  '362,706',
#  '362,706',
#  '۲۵ اسفند',
#  '420,750',
#  '(0%) 0',
#  '420,750',
#  '420,750',
#  '۲۳ اسفند',
#  '393996',
#  '(0%) 0',
#  '393366',
#  '394535',
#  '۳ بهمن',
#  '500,000',
#  '(0%) 0',
#  '475,000',
#  '500,000',
#  '۲۸ اسفند']

# %%
import pandas as pd
import numpy as np

# %%
column=[]
for j in range(6):
    column.append(soup.body.find(id="main").tbody.find_all(["th"])[j].text)
    j=j+1
column
# Out:
# [' دلار',
#  ' دلار سنا / خرید',
#  ' دلار نیما / خرید',
#  ' دلار صرافی\u200c ملی / خرید',
#  ' دلار توافقی',
#  ' دلار هرات']

# %%
dt_row=np.array_split(dt,6)

# %%
dollar_prices=pd.DataFrame(data=dt_row,index=column)

# %%
dollar_prices
# Out:
#                                0       1        2        3         4
#  دلار                    472,080  (0%) 0  460,800  472,100  ۲۸ اسفند
#  دلار سنا / خرید         398,382  (0%) 0  398,382  398,382  ۲۵ اسفند
#  دلار نیما / خرید        362,706  (0%) 0  362,706  362,706  ۲۵ اسفند
#  دلار صرافی‌ ملی / خرید  420,750  (0%) 0  420,750  420,750  ۲۳ اسفند
#  دلار توافقی              393996  (0%) 0   393366   394535    ۳ بهمن
#  دلار هرات               500,000  (0%) 0  475,000  500,000  ۲۸ اسفند

# %%
dollar_prices.to_csv(r"F:\h\a.csv", encoding='utf-8')

# %%
#pip install pyodbc

# %%
import pyodbc
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=localhost;'
                      'Database=master;'
                      'Trusted_Connection=yes;')

# %%
cursor.execute("ALTER TABLE dbo.Dollar_na ALTER COLUMN Price NVARCHAR(32) NOT NULL;")

# %%
# PREPARED STATEMENT (NO DATA)
query = "insert into Dollar_na values (?, ?, ?,?,?)"

# LIST OF TUPLES FOR PARAMS
for i in range(6):
    if i==[0,1,2]:
        i=+1
    else:
        data = [(dollar_prices[0][i], dollar_prices[1][i], dollar_prices[2][i],dollar_prices[3][i],dollar_prices[4][i])]
        cursor.executemany(query, data)
        cursor.commit()
# EXECUTE STATEMENT AND BIND PARAMS
#cursor.executemany(query, data)
#cursor.commit()

# %%
cursor.execute("Select * from Dollar.dbo.Dollar_na")

# %%
#cursor.execute("DELETE top (3) FROM Dollar.dbo.Dollar_na;")

# %%
for i in cursor:
    print(i)
# Out:
# (Decimal('16'), '472,080', '(0%) 0', '460,800', '472,100', '?? ?????')
# (Decimal('17'), '398,382', '(0%) 0', '398,382', '398,382', '?? ?????')
# (Decimal('18'), '362,706', '(0%) 0', '362,706', '362,706', '?? ?????')
# (Decimal('10'), '472,080', '(0%) 0', '460,800', '472,100', '?? ?????')
# (Decimal('11'), '398,382', '(0%) 0', '398,382', '398,382', '?? ?????')
# (Decimal('12'), '362,706', '(0%) 0', '362,706', '362,706', '?? ?????')
# (Decimal('13'), '420,750', '(0%) 0', '420,750', '420,750', '?? ?????')
# (Decimal('14'), '393996', '(0%) 0', '393366', '394535', '? ????')
# (Decimal('15'), '500,000', '(0%) 0', '475,000', '500,000', '?? ?????')
# (Decimal('19'), '420,750', '(0%) 0', '420,750', '420,750', '?? ?????')
# (Decimal('20'), '393996', '(0%) 0', '393366', '394535', '? ????')
# (Decimal('21'), '500,000', '(0%) 0', '475,000', '500,000', '?? ?????')

# %%
dollar_prices[0][0]
# Out:
# '472,080'

# %%
import schedule
import time
from os import system

def job():
    system("Crawler and import in MSSQL.py")


schedule.every(1).hours.do(job)

while True:
    schedule.run_pending()
    time.sleep(1)
